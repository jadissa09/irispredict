# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
iris=load_iris()
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2744\2015792489.py in <module>
#       1 df=pd.DataFrame(iris.data,columns=iris.feature_names)
# ----> 2 df.target
#
# c:\Users\Lenovo\Documents\projects\ML\irispredict\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %%
df[:200]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df['target']=iris.target

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
x=df.drop(['target'],axis=1).values
y=df[['target']].values

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
xtrain=m.fit_transform(xtrain)
xtest=m.transform(xtest)

# %%
import pickle
pickle.dump(m,open('scaling.pkl','wb'))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

penalty=['l1','l2']
max_iter=[80,100,140]
C=np.linspace(0.1,1,num=5)

# %%
param_grid=dict(max_iter=max_iter,C=C,penalty=penalty)
liris=LogisticRegression(multi_class="multinomial",solver='saga')
grid=GridSearchCV(estimator=liris,param_grid=param_grid,cv=5)
grid_result=grid.fit(xtrain,ytrain)
grid_result.best_score_,grid_result.best_params_
# Out:
# c:\Users\Lenovo\Documents\projects\ML\irispredict\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Lenovo\Documents\projects\ML\irispredict\venv\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# c:\Users\Lenovo\Documents\projects\ML\irispredict\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
model=LogisticRegression(multi_class="multinomial",solver='saga',C= 0.775, max_iter= 80, penalty= 'l1')
model.fit(xtrain,ytrain)
ypred=model.predict(xtest)
from sklearn.metrics import accuracy_score
accuracy_score(ytest,ypred)
newdatapred=[[6,3,5,2]]
newdatascaler=m.transform(newdatapred)
model.predict(newdatascaler)
# Out:
# c:\Users\Lenovo\Documents\projects\ML\irispredict\venv\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Lenovo\Documents\projects\ML\irispredict\venv\lib\site-packages\sklearn\linear_model\_sag.py:354: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   ConvergenceWarning,
# array([2])

# %%
import pickle
pickle.dump(model,open('irisreg.pkl','wb'))
